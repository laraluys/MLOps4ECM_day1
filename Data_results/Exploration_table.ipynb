# %% [markdown]
# # Tabular data exploration

# %% [markdown]
# ## Imports needed for data exploration

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data importation

# %% [markdown]
# For tabular data we are using a water potability dataset which can be found on [Kaggle](https://www.kaggle.com/datasets/adityakadiwal/water-potability). This dataset is located in our directory under "datasets/water_potability" and has a csv file format.</br></br>
# Before we can do anything with our dataset we need to load it into python. The easiest way to read and work with tabular data is to use the Pandas library. </br>
# To read data from a csv file we use the following command:
#
# <code> data = pd.read_csv("pathname/to/dataset.csv", delimiter="," , index_col=None) </code>
#
# This code creates a pandas.DataFrame type. This type has a number of methods to obtain some basic insights into the data: (1) <code>.head(n)</code> to see the first n rows in the dataframe, (2) <code>.info()</code> to see general information about the columns and dataframe, and (3) <code>.describe()</code> to see basic statistics for each feature. Use these methods to explore the dataframe and answer the following questions:
#
# What is the number of rows in the dataframe: 3279
#
# What is the number of columns in the dataframe: 11
#
# What is the number of features in the data: 10
#
# What is the memory usage of the dataframe: 281.7 KB

# %%
data = pd.read_csv("datasets/water_potability/water_potability.csv", delimiter=";")

# %%
data.head()
# Out:
#          ph        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Hardness_2  Hardness_1  \
# 0       10.379783        86.990970   2.963135  204.890455         NaN
# 1       15.180013        56.329076   4.500656  129.422921         NaN
# 2       16.868637        66.420093   3.055934  224.236259         NaN
# 3       18.436524       100.341674   4.628771  214.373394 -161.809536
# 4       11.558279        31.997993   4.075075  181.101509 -136.883422
#
#    Potability
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Solids           3276 non-null   float64
#  2   Chloramines      3276 non-null   float64
#  3   Sulfate          2495 non-null   float64
#  4   Conductivity     3276 non-null   float64
#  5   Organic_carbon   3276 non-null   float64
#  6   Trihalomethanes  3114 non-null   float64
#  7   Turbidity        3276 non-null   float64
#  8   Hardness_2       3276 non-null   float64
#  9   Hardness_1       2116 non-null   float64
#  10  Potability       3276 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 281.7 KB

# %%
data.describe()
# Out:
#                 ph        Solids  Chloramines      Sulfate  Conductivity  \
# count  2785.000000   3276.000000  3276.000000  2495.000000   3276.000000
# mean      7.080795  22014.092526     7.122277   333.775777    426.205111
# std       1.594320   8768.570828     1.583085    41.416840     80.824064
# min       0.000000    320.942611     0.352000   129.000000    181.483754
# 25%       6.093092  15666.690297     6.127421   307.699498    365.734414
# 50%       7.036752  20927.833607     7.130299   333.073546    421.884968
# 75%       8.062066  27332.762127     8.114887   359.950170    481.792304
# max      14.000000  61227.196008    13.127000   481.030642    753.342620
#
#        Organic_carbon  Trihalomethanes    Turbidity   Hardness_2   Hardness_1  \
# count     3276.000000      3114.000000  3276.000000  3276.000000  2116.000000
# mean        14.284970        66.396293     3.966786   196.369496  -152.488808
# std          3.308162        16.175008     0.780382    32.879761    20.728086
# min          2.200000         0.738000     1.450000    47.432000  -230.399848
# 25%         12.065801        55.844536     3.439711   176.850538  -165.128288
# 50%         14.218338        66.622485     3.955028   196.967627  -152.207243
# 75%         16.557652        77.337473     4.500320   216.667456  -139.958422
# max         28.300000       124.000000     6.739000   323.124000   -46.615908
#
#         Potability
# count  3276.000000
# mean      0.390110
# std       0.487849
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# ## Explore the data

# %% [markdown]
# ### Null values
#
# An important aspect of your dataset is that it is "clean". This means that there are no None, Null, NaN or other values given in the dataset.</br>
# Using Pandas it is easy to find the exact amount of none-values using the following command:
#
# <code>number_of_nan_in_column = dataframe["column_name"].isnull().sum() </code>

# %%
count_nan_ph = data['ph'].isnull().sum()
print("The amount of NaN values in the ph column is: " + str(count_nan_ph))

count_nan_hardness = data['Hardness_1'].isnull().sum()
print("The amount of NaN values in the Hardness_1 column is: " + str(count_nan_hardness))

count_nan_hardness = data['Hardness_2'].isnull().sum()
print("The amount of NaN values in the Hardness_2 column is: " + str(count_nan_hardness))

count_nan_solids = data['Solids'].isnull().sum()
print("The amount of NaN values in the Solids column is: " + str(count_nan_solids))

count_nan_chloramines = data['Chloramines'].isnull().sum()
print("The amount of NaN values in the Chloramines column is: " + str(count_nan_chloramines))

count_nan_sulfate = data['Sulfate'].isnull().sum()
print("The amount of NaN values in the Sulfate column is: " + str(count_nan_sulfate))

count_nan_conductivity = data['Conductivity'].isnull().sum()
print("The amount of NaN values in the conductivity column is: " + str(count_nan_conductivity))

count_nan_organic_carbon = data['Organic_carbon'].isnull().sum()
print("The amount of NaN values in the Organic_carbon column is: " + str(count_nan_organic_carbon))

count_nan_trihalomethanes = data['Trihalomethanes'].isnull().sum()
print("The amount of NaN values in the Trihalomethanes column is: " + str(count_nan_trihalomethanes))

count_nan_turbidity = data['Turbidity'].isnull().sum()
print("The amount of NaN values in the Turbidity column is: " + str(count_nan_turbidity))

count_nan_potability = data['Potability'].isnull().sum()
print("The amount of NaN values in the Potability column is: " + str(count_nan_potability))
# Out:
# The amount of NaN values in the ph column is: 491
# The amount of NaN values in the Hardness_1 column is: 1160
# The amount of NaN values in the Hardness_2 column is: 0
# The amount of NaN values in the Solids column is: 0
# The amount of NaN values in the Chloramines column is: 0
# The amount of NaN values in the Sulfate column is: 781
# The amount of NaN values in the conductivity column is: 0
# The amount of NaN values in the Organic_carbon column is: 0
# The amount of NaN values in the Trihalomethanes column is: 162
# The amount of NaN values in the Turbidity column is: 0
# The amount of NaN values in the Potability column is: 0

# %% [markdown]
# ### Feature distribution
# Sometimes the different features/variables in your dataset can have different ranges. This seams fine at first glance but can cause problems in certain algorithms like Gradient Descent where variables with larger values can have a larger affect on your gradients than variables with smaller values. Therefore it is a good idea to create histograms of your different variables to know which values have which ranges. It can also give you more information about the different distributions of the parameters, this can be especially interesting with the labels where an underrepresentation of a certain class could cause a problem in the classification. </br>
# Use the following command to show the different histograms of the columns in your pandas dataframe:
#
# <code>dataframe.hist(figsize=[width_in_inch, height_in_inch])</code>

# %%
data.hist(figsize=[12,12])
# Out:
# array([[<Axes: title={'center': 'ph'}>,
#         <Axes: title={'center': 'Solids'}>,
#         <Axes: title={'center': 'Chloramines'}>],
#        [<Axes: title={'center': 'Sulfate'}>,
#         <Axes: title={'center': 'Conductivity'}>,
#         <Axes: title={'center': 'Organic_carbon'}>],
#        [<Axes: title={'center': 'Trihalomethanes'}>,
#         <Axes: title={'center': 'Turbidity'}>,
#         <Axes: title={'center': 'Hardness_2'}>],
#        [<Axes: title={'center': 'Hardness_1'}>,
#         <Axes: title={'center': 'Potability'}>, <Axes: >]], dtype=object)

# %% [markdown]
# ### Correlations
# When working with large datasets there might be too many features making training and inference on your dataset very slow. In those situations there is a higher chance that some features are not necessary. This can be checked by creating a correlation matrix between the different features. There are several different ways to calculate this like the "spearman" or "pearson" correlation values. Both show the correlation with values between -1 and 1 where -1 means a negative correltation and 1 a positive correlation. With Pandas, these correlation matrices can be calculated as follows:
#
# <code>dataframe.corr("spearman")</code>
#
# </br>
# To make the matrix more readable you have several options. The first one is to use matplotlib:
#
# <code>plt.matshow(matrix)</br>
# plt.colorbar()</br>
# plt.show()</br>
# </code>
#
# </br>
# A second option is to use seaborn. There you create a subplot using matplotlib and then create a heatmap using seaborn:
#
# <code>
# f, ax = plt.subplots()</br>
# sns.heatmap(matrix, vmin=minimum, vmax=maximum, ax=ax)
# </code>
#
# One of the two Hardness columns is the real Hardness, the other is just a combination of two other columns in the dataset. Which one is the real one? Hardness_2

# %%
data.corr("spearman")
# Out:
#                        ph    Solids  Chloramines   Sulfate  Conductivity  \
# ph               1.000000 -0.075239    -0.042486  0.023552      0.016920
# Solids          -0.075239  1.000000    -0.055037 -0.154223      0.021089
# Chloramines     -0.042486 -0.055037     1.000000  0.037229     -0.016928
# Sulfate          0.023552 -0.154223     0.037229  1.000000     -0.022277
# Conductivity     0.016920  0.021089    -0.016928 -0.022277      1.000000
# Organic_carbon   0.043534  0.017881    -0.011910  0.019590      0.021311
# Trihalomethanes  0.004672 -0.019618     0.017784 -0.031157     -0.004094
# Turbidity       -0.049050  0.028470    -0.007909 -0.018826      0.010342
# Hardness_2       0.116266 -0.052584    -0.024556 -0.094803     -0.032884
# Hardness_1       0.127608  0.127665    -0.029592 -0.985132      0.019914
# Potability      -0.002181  0.026234     0.024980 -0.016676     -0.010386
#
#                  Organic_carbon  Trihalomethanes  Turbidity  Hardness_2  \
# ph                     0.043534         0.004672  -0.049050    0.116266
# Solids                 0.017881        -0.019618   0.028470   -0.052584
# Chloramines           -0.011910         0.017784  -0.007909   -0.024556
# Sulfate                0.019590        -0.031157  -0.018826   -0.094803
# Conductivity           0.021311        -0.004094   0.010342   -0.032884
# Organic_carbon         1.000000        -0.008053  -0.024730    0.003340
# Trihalomethanes       -0.008053         1.000000  -0.027801   -0.011667
# Turbidity             -0.024730        -0.027801   1.000000   -0.012855
# Hardness_2             0.003340        -0.011667  -0.012855    1.000000
# Hardness_1            -0.012632         0.028080   0.006091    0.113143
# Potability            -0.026774         0.005307   0.001088   -0.010606
#
#                  Hardness_1  Potability
# ph                 0.127608   -0.002181
# Solids             0.127665    0.026234
# Chloramines       -0.029592    0.024980
# Sulfate           -0.985132   -0.016676
# Conductivity       0.019914   -0.010386
# Organic_carbon    -0.012632   -0.026774
# Trihalomethanes    0.028080    0.005307
# Turbidity          0.006091    0.001088
# Hardness_2         0.113143   -0.010606
# Hardness_1         1.000000    0.018141
# Potability         0.018141    1.000000

# %%
f, ax = plt.subplots()
corr = data.corr("spearman")
sns.heatmap(corr, vmin=-1.0, vmax=1.0, ax=ax)
# Out:
# <Axes: >

# %%
data_new = data.drop("Hardness_1", axis=1)
